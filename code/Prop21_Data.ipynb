# %%
import pandas as pd
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# import data about popluation and age over entire state CA

########
df2019_Population = pd.read_excel(open('rawdata/Web_ACS2019_Pop-Race.xlsx', 'rb'),
                       sheet_name='Total Pop & Median Age', comment='#', 
                       header = 4, usecols = "A,B")

df2019_Population_County = df2019_Population[df2019_Population.Geography.str.contains('County',case=False)]
df2019_Population_County = df2019_Population_County.rename(columns = {"Total Population - Estimate":"2019"})

########
df2018_Population = pd.read_excel(open('rawdata/Web_ACS2018_Pop-Race.xlsx', 'rb'),
                       sheet_name='Total Pop & Median Age', comment='#', 
                       header = 4, usecols = "A,B")

df2018_Population_County = df2018_Population[df2018_Population.Geography.str.contains('County',case=False)]
df2018_Population_County = df2018_Population_County.rename(columns = {"Total Population - Estimate":"2018"})

########

df2017_Population = pd.read_excel(open('rawdata/Web_ACS2017_Pop-Race.xlsx', 'rb'),
                       sheet_name='Total Pop & Median Age', comment='#', 
                       header = 5, usecols = "A,B")

df2017_Population_County = df2017_Population[df2017_Population.Geography.str.contains('County',case=False)]
df2017_Population_County = df2017_Population_County.rename(columns = {"Estimate":"2017"})



########

df2016_Population = pd.read_excel(open('rawdata/Web_ACS2016_Pop-Race.xlsx', 'rb'),
                       sheet_name='Total Pop & Median Age', comment='#', 
                       header = 5, usecols = "A,B")

df2016_Population_County = df2016_Population[df2016_Population.Geography.str.contains('County',case=False)]
df2016_Population_County = df2016_Population_County.rename(columns = {"Estimate":"2016"})


########

df2015_Population = pd.read_excel(open('rawdata/Web_ACS2015_Pop-Race.xlsx', 'rb'),
                       sheet_name='Total Pop & Median Age', comment='#', 
                       header = 5, usecols = "A,B")

df2015_Population_County = df2015_Population[df2015_Population.Geography.str.contains('County',case=False)]
df2015_Population_County = df2015_Population_County.rename(columns ={"Estimate":"2015"})

########


df2014_Population = pd.read_excel(open('rawdata/Web_ACS2014_Pop-Race.xlsx', 'rb'),
                       sheet_name='Total Pop & Median Age', comment='#', 
                       header = 5, usecols = "A,B")

df2014_Population_County = df2014_Population[df2014_Population.Geography.str.contains('County',case=False)]
df2014_Population_County = df2014_Population_County.rename(columns = {"Estimate":"2014"})

########


df2013_Population = pd.read_excel(open('rawdata/Web_ACS2013_Pop-Race.xls', 'rb'),
                       sheet_name='Total Pop & Median Age', comment='#', 
                       header = 5, usecols = "A,B")

df2013_Population_County = df2013_Population[df2013_Population.Geography.str.contains('County',case=False)]
df2013_Population_County = df2013_Population_County.rename(columns = {"Estimate":"2013"})



########
df2012_Population = pd.read_excel(open('rawdata/Web_ACS2012_Pop-Race.xls', 'rb'),
                       sheet_name='Total Pop & Median Age', comment='#', 
                       header = 5, usecols = "A,B")

df2012_Population_County = df2012_Population[df2012_Population.Geography.str.contains('County',case=False)]
df2012_Population_County = df2012_Population_County.rename(columns = {"Estimate":"2012"})

########

df2011_Population = pd.read_excel(open('rawdata/Web_ACS2011_Pop-Race.xlsx', 'rb'),
                       sheet_name='Total Pop & Median Age', comment='#', 
                       header = 5, usecols = "A,B")

df2011_Population_County = df2011_Population[df2011_Population.Geography.str.contains('County',case=False)]
df2011_Population_County = df2011_Population_County.rename(columns = {"Estimate":"2011"})

########

df2010_Population = pd.read_excel(open('rawdata/Web_ACS2010_Pop-Race.xlsx', 'rb'),
                       sheet_name='Total Pop & Median Age', comment='#', 
                       header = 5, usecols = "A,B")

df2010_Population_County = df2010_Population[df2010_Population.Geography.str.contains('County',case=False)]
df2010_Population_County = df2010_Population_County.rename(columns = {"Estimate":"2010"})

########

# %%
##########
### collection population for each county in CA

df_Population_County = pd.merge(df2010_Population_County,df2011_Population_County, on='Geography',how='outer')
df_Population_County = pd.merge(df_Population_County,df2012_Population_County, on='Geography',how='outer')
df_Population_County = pd.merge(df_Population_County,df2013_Population_County, on='Geography',how='outer')
df_Population_County = pd.merge(df_Population_County,df2014_Population_County, on='Geography',how='outer')
df_Population_County = pd.merge(df_Population_County,df2015_Population_County, on='Geography',how='outer')
df_Population_County = pd.merge(df_Population_County,df2016_Population_County, on='Geography',how='outer')
df_Population_County = pd.merge(df_Population_County,df2017_Population_County, on='Geography',how='outer')
df_Population_County = pd.merge(df_Population_County,df2018_Population_County, on='Geography',how='outer')
df_Population_County = pd.merge(df_Population_County,df2019_Population_County, on='Geography',how='outer')

#############

df_Population_County = df_Population_County[:-1]
df_Population_County['average'] = df_Population_County.mean(axis=1)
df_Population_County_avg = df_Population_County[['Geography','average']]
df_Population_County_avg = df_Population_County_avg.rename(columns = {"average":"population_avg"})

# %%
# import data about Median_household_income, Median_family_income over entire state CA

########
df2019_Median_household_income = pd.read_excel(open('rawdata/Web_ACS2019_Inc-Pov-Emp.xlsx', 'rb'),
                       sheet_name='Income', comment='#', 
                       header = 4, usecols = "A,B")
df2019_Median_household_income_county = df2019_Median_household_income[df2019_Median_household_income.Geography.str.contains('County',case=False)]
df2019_Median_household_income_county = df2019_Median_household_income_county.rename(columns = {"Median household income (dollars) - Estimate":"2019"})

#####

df2019_Median_family_income = pd.read_excel(open('rawdata/Web_ACS2019_Inc-Pov-Emp.xlsx', 'rb'),
                       sheet_name='Income', comment='#', 
                       header = 4, usecols = "A,F")
df2019_Median_family_income_county = df2019_Median_family_income[df2019_Median_family_income.Geography.str.contains('County',case=False)]
df2019_Median_family_income_county = df2019_Median_family_income_county.rename(columns = {"Median family income (dollars) - \nEstimate":"2019"})



########
df2018_Median_household_income = pd.read_excel(open('rawdata/Web_ACS2018_Inc-Pov-Emp.xlsx', 'rb'),
                       sheet_name='Income', comment='#', 
                       header = 4, usecols = "A,B")
df2018_Median_household_income_county = df2018_Median_household_income[df2018_Median_household_income.Geography.str.contains('County',case=False)]
df2018_Median_household_income_county = df2018_Median_household_income_county.rename(columns = {"Median household income (dollars) - Estimate":"2018"})

######
df2018_Mean_household_income = pd.read_excel(open('rawdata/Web_ACS2018_Inc-Pov-Emp.xlsx', 'rb'),
                       sheet_name='Income', comment='#', 
                       header = 4, usecols = "A,D")
df2018_Mean_household_income_county = df2018_Mean_household_income[df2018_Mean_household_income.Geography.str.contains('County',case=False)]
df2018_Mean_household_income_county = df2018_Mean_household_income_county.rename(columns = {"Mean household income (dollars) - Estimate":"2018"})

#####


df2018_Median_family_income = pd.read_excel(open('rawdata/Web_ACS2018_Inc-Pov-Emp.xlsx', 'rb'),
                       sheet_name='Income', comment='#', 
                       header = 4, usecols = "A,F")
df2018_Median_family_income_county = df2018_Median_family_income[df2018_Median_family_income.Geography.str.contains('County',case=False)]
df2018_Median_family_income_county = df2018_Median_family_income_county.rename(columns = {"Median family income (dollars) - \nEstimate":"2018"})




########
df2017_Median_household_income = pd.read_excel(open('rawdata/Web_ACS2017_Inc-Pov-Emp.xlsx', 'rb'),
                       sheet_name='Income', comment='#', 
                       header = 4, usecols = "A,B")
df2017_Median_household_income_county = df2017_Median_household_income[df2017_Median_household_income.Geography.str.contains('County',case=False)]
df2017_Median_household_income_county = df2017_Median_household_income_county.rename(columns = {"Estimate":"2017"})

#######

df2017_Median_family_income = pd.read_excel(open('rawdata/Web_ACS2017_Inc-Pov-Emp.xlsx', 'rb'),
                       sheet_name='Income', comment='#', 
                       header = 4, usecols = "A,F")
df2017_Median_family_income_county = df2017_Median_family_income[df2017_Median_family_income.Geography.str.contains('County',case=False)]
df2017_Median_family_income_county = df2017_Median_family_income_county.rename(columns = {"Estimate.2":"2017"})



########
df2016_Median_household_income = pd.read_excel(open('rawdata/Web_ACS2016_Inc-Pov-Emp.xlsx', 'rb'),
                       sheet_name='Income', comment='#', 
                       header = 4, usecols = "A,B")
df2016_Median_household_income_county = df2016_Median_household_income[df2016_Median_household_income.Geography.str.contains('County',case=False)]
df2016_Median_household_income_county = df2016_Median_household_income_county.rename(columns = {"Estimate":"2016"})


#######

df2016_Median_family_income = pd.read_excel(open('rawdata/Web_ACS2016_Inc-Pov-Emp.xlsx', 'rb'),
                       sheet_name='Income', comment='#', 
                       header = 4, usecols = "A,F")
df2016_Median_family_income_county = df2016_Median_family_income[df2016_Median_family_income.Geography.str.contains('County',case=False)]
df2016_Median_family_income_county = df2016_Median_family_income_county.rename(columns = {"Estimate.2":"2016"})




########

df2015_Median_household_income = pd.read_excel(open('rawdata/Web_ACS2015_Inc-Pov-Emp.xlsx', 'rb'),
                       sheet_name='Income', comment='#', 
                       header = 4, usecols = "A,B")
df2015_Median_household_income_county = df2015_Median_household_income[df2015_Median_household_income.Geography.str.contains('County',case=False)]
df2015_Median_household_income_county = df2015_Median_household_income_county.rename(columns = {"Estimate":"2015"})


########


df2015_Median_family_income = pd.read_excel(open('rawdata/Web_ACS2015_Inc-Pov-Emp.xlsx', 'rb'),
                       sheet_name='Income', comment='#', 
                       header = 4, usecols = "A,F")
df2015_Median_family_income_county = df2015_Median_family_income[df2015_Median_family_income.Geography.str.contains('County',case=False)]
df2015_Median_family_income_county = df2015_Median_family_income_county.rename(columns = {"Estimate.2":"2015"})



########
df2014_Median_household_income = pd.read_excel(open('rawdata/Web_ACS2014_Inc-Pov-Emp.xlsx', 'rb'),
                       sheet_name='Income', comment='#', 
                       header = 4, usecols = "A,B")
df2014_Median_household_income_county = df2014_Median_household_income[df2014_Median_household_income.Geography.str.contains('County',case=False)]
df2014_Median_household_income_county = df2014_Median_household_income_county.rename(columns = {"Estimate":"2014"})

#######

df2014_Median_family_income = pd.read_excel(open('rawdata/Web_ACS2014_Inc-Pov-Emp.xlsx', 'rb'),
                       sheet_name='Income', comment='#', 
                       header = 4, usecols = "A,F")
df2014_Median_family_income_county = df2014_Median_family_income[df2014_Median_family_income.Geography.str.contains('County',case=False)]
df2014_Median_family_income_county = df2014_Median_family_income_county.rename(columns = {"Estimate.2":"2014"})




########
df2013_Median_household_income = pd.read_excel(open('rawdata/Web_ACS2013_Inc-Pov-Emp.xls', 'rb'),
                       sheet_name='Income', comment='#', 
                       header = 4, usecols = "A,B")
df2013_Median_household_income_county = df2013_Median_household_income[df2013_Median_household_income.Geography.str.contains('County',case=False)]
df2013_Median_household_income_county = df2013_Median_household_income_county.rename(columns = {"Estimate":"2013"})

#######

df2013_Median_family_income = pd.read_excel(open('rawdata/Web_ACS2013_Inc-Pov-Emp.xls', 'rb'),
                       sheet_name='Income', comment='#', 
                       header = 4, usecols = "A,F")
df2013_Median_family_income_county = df2013_Median_family_income[df2013_Median_family_income.Geography.str.contains('County',case=False)]
df2013_Median_family_income_county = df2013_Median_family_income_county.rename(columns = {"Estimate.2":"2013"})



########
df2012_Median_household_income = pd.read_excel(open('rawdata/Web_ACS2012_Inc-Pov-Emp.xls', 'rb'),
                       sheet_name='Income', comment='#', 
                       header = 5, usecols = "A,B")
df2012_Median_household_income_county = df2012_Median_household_income[df2012_Median_household_income.Geography.str.contains('County',case=False)]
df2012_Median_household_income_county = df2012_Median_household_income_county.rename(columns = {"Estimate":"2012"})


######

df2012_Median_family_income = pd.read_excel(open('rawdata/Web_ACS2012_Inc-Pov-Emp.xls', 'rb'),
                       sheet_name='Income', comment='#', 
                       header = 5, usecols = "A,F")
df2012_Median_family_income_county = df2012_Median_family_income[df2012_Median_family_income.Geography.str.contains('County',case=False)]
df2012_Median_family_income_county = df2012_Median_family_income_county.rename(columns = {"Estimate.2":"2012"})



########
df2011_Median_household_income = pd.read_excel(open('rawdata/Web_ACS2011_Inc-Pov-Emp.xls', 'rb'),
                       sheet_name='Income', comment='#', 
                       header = 4, usecols = "A,B")
df2011_Median_household_income_county = df2011_Median_household_income[df2011_Median_household_income.Geography.str.contains('County',case=False)]
df2011_Median_household_income_county = df2011_Median_household_income_county.rename(columns = {"Estimate":"2011"})

######

df2011_Median_family_income = pd.read_excel(open('rawdata/Web_ACS2011_Inc-Pov-Emp.xls', 'rb'),
                       sheet_name='Income', comment='#', 
                       header = 4, usecols = "A,F")
df2011_Median_family_income_county = df2011_Median_family_income[df2011_Median_family_income.Geography.str.contains('County',case=False)]
df2011_Median_family_income_county = df2011_Median_family_income_county.rename(columns = {"Estimate.2":"2011"})



########
df2010_Median_household_income = pd.read_excel(open('rawdata/Web_ACS2010_Inc-Pov-Emp.xls', 'rb'),
                       sheet_name='Income', comment='#', 
                       header = 4, usecols = "A,B")
df2010_Median_household_income_county = df2010_Median_household_income[df2010_Median_household_income.Geography.str.contains('County',case=False)]
df2010_Median_household_income_county = df2010_Median_household_income_county.rename(columns = {"Estimate":"2010"})

########

df2010_Median_family_income = pd.read_excel(open('rawdata/Web_ACS2010_Inc-Pov-Emp.xls', 'rb'),
                       sheet_name='Income', comment='#', 
                       header = 4, usecols = "A,F")
df2010_Median_family_income_county = df2010_Median_family_income[df2010_Median_family_income.Geography.str.contains('County',case=False)]
df2010_Median_family_income_county = df2010_Median_family_income_county.rename(columns = {"Estimate.2":"2010"})

# %%
########
### collect Median household income for each county 

df_Median_household_income_county = pd.merge(df2010_Median_household_income_county,df2011_Median_household_income_county, on='Geography',how='outer')
df_Median_household_income_county = pd.merge(df_Median_household_income_county,df2012_Median_household_income_county, on='Geography',how='outer')
df_Median_household_income_county = pd.merge(df_Median_household_income_county,df2013_Median_household_income_county, on='Geography',how='outer')
df_Median_household_income_county = pd.merge(df_Median_household_income_county,df2014_Median_household_income_county, on='Geography',how='outer')
df_Median_household_income_county = pd.merge(df_Median_household_income_county,df2015_Median_household_income_county, on='Geography',how='outer')
df_Median_household_income_county = pd.merge(df_Median_household_income_county,df2016_Median_household_income_county, on='Geography',how='outer')
df_Median_household_income_county = pd.merge(df_Median_household_income_county,df2017_Median_household_income_county, on='Geography',how='outer')
df_Median_household_income_county = pd.merge(df_Median_household_income_county,df2018_Median_household_income_county, on='Geography',how='outer')
df_Median_household_income_county = pd.merge(df_Median_household_income_county,df2019_Median_household_income_county, on='Geography',how='outer')


########

df_Median_household_income_county = df_Median_household_income_county[:-1]
df_Median_household_income_county['average'] = df_Median_household_income_county.mean(axis=1)

# %%
##### 
### median family income for each county 

df_Median_family_income_county = pd.merge(df2010_Median_family_income_county,df2011_Median_family_income_county, on='Geography',how='outer')
df_Median_family_income_county = pd.merge(df_Median_family_income_county,df2012_Median_family_income_county, on='Geography',how='outer')
df_Median_family_income_county = pd.merge(df_Median_family_income_county,df2013_Median_family_income_county, on='Geography',how='outer')
df_Median_family_income_county = pd.merge(df_Median_family_income_county,df2014_Median_family_income_county, on='Geography',how='outer')
df_Median_family_income_county = pd.merge(df_Median_family_income_county,df2015_Median_family_income_county, on='Geography',how='outer')
df_Median_family_income_county = pd.merge(df_Median_family_income_county,df2016_Median_family_income_county, on='Geography',how='outer')
df_Median_family_income_county = pd.merge(df_Median_family_income_county,df2017_Median_family_income_county, on='Geography',how='outer')
df_Median_family_income_county = pd.merge(df_Median_family_income_county,df2018_Median_family_income_county, on='Geography',how='outer')
df_Median_family_income_county = pd.merge(df_Median_family_income_county,df2019_Median_family_income_county, on='Geography',how='outer')

#######
df_Median_family_income_county = df_Median_family_income_county[:-1]
df_Median_family_income_county['average'] = df_Median_family_income_county.mean(axis=1)

# %%
#######

#### import data about rent over entire state CA


df2019_Median_Renter = pd.read_excel(open('rawdata/Web_ACS2019_Housing.xlsx', 'rb'),
                       sheet_name='Renter Costs', comment='#', 
                       header = 4, usecols = "A, B")
df2019_Median_Renter_county = df2019_Median_Renter[df2019_Median_Renter.Geography.str.contains('County',case=False)]
df2019_Median_Renter_county = df2019_Median_Renter_county.rename(columns = {"GROSS RENT - Median (dollars) - \nEstimate":"2019"})


df2018_Median_Renter = pd.read_excel(open('rawdata/Web_ACS2018_Housing.xlsx', 'rb'),
                       sheet_name='Renter Costs', comment='#', 
                       header = 4, usecols = "A, B")
df2018_Median_Renter_county = df2018_Median_Renter[df2018_Median_Renter.Geography.str.contains('County',case=False)]
df2018_Median_Renter_county = df2018_Median_Renter_county.rename(columns = {"GROSS RENT - Median (dollars) - \nEstimate":"2018"})

#######
df2017_Median_Renter = pd.read_excel(open('rawdata/Web_ACS2017_Housing.xlsx', 'rb'),
                       sheet_name='Renter Costs', comment='#', 
                       header = 5, usecols = "A, B")
df2017_Median_Renter_county = df2017_Median_Renter[df2017_Median_Renter.Geography.str.contains('County',case=False)]
df2017_Median_Renter_county = df2017_Median_Renter_county.rename(columns = {"Estimate":"2017"})


######
df2016_Median_Renter = pd.read_excel(open('rawdata/Web_ACS2016_Housing.xlsx', 'rb'),
                       sheet_name='Renter Costs', comment='#', 
                       header = 5, usecols = "A, B")
df2016_Median_Renter_county = df2016_Median_Renter[df2016_Median_Renter.Geography.str.contains('County',case=False)]
df2016_Median_Renter_county = df2016_Median_Renter_county.rename(columns = {"Estimate":"2016"})


######
df2015_Median_Renter = pd.read_excel(open('rawdata/Web_ACS2015_Housing.xlsx', 'rb'),
                       sheet_name='Renter Costs', comment='#', 
                       header = 5, usecols = "A, B")
df2015_Median_Renter_county = df2015_Median_Renter[df2015_Median_Renter.Geography.str.contains('County',case=False)]
df2015_Median_Renter_county = df2015_Median_Renter_county.rename(columns = {"Estimate":"2015"})




######
df2014_Median_Renter = pd.read_excel(open('rawdata/Web_ACS2014_Housing.xlsx', 'rb'),
                       sheet_name='Renter Costs', comment='#', 
                       header = 5, usecols = "A, B")
df2014_Median_Renter_county = df2014_Median_Renter[df2014_Median_Renter.Geography.str.contains('County',case=False)]
df2014_Median_Renter_county = df2014_Median_Renter_county.rename(columns = {"Estimate":"2014"})




######
df2013_Median_Renter = pd.read_excel(open('rawdata/Web_ACS2013_Housing.xls', 'rb'),
                       sheet_name='Renter Costs', comment='#', 
                       header = 5, usecols = "A, B")
df2013_Median_Renter_county = df2013_Median_Renter[df2013_Median_Renter.Geography.str.contains('County',case=False)]
df2013_Median_Renter_county = df2013_Median_Renter_county.rename(columns = {"Estimate":"2013"})




######
df2012_Median_Renter = pd.read_excel(open('rawdata/Web_ACS2012_Housing.xls', 'rb'),
                       sheet_name='Renter Costs', comment='#', 
                       header = 5, usecols = "A, B")
df2012_Median_Renter_county = df2012_Median_Renter[df2012_Median_Renter.Geography.str.contains('County',case=False)]
df2012_Median_Renter_county = df2012_Median_Renter_county.rename(columns = {"Estimate":"2012"})




######
df2011_Median_Renter = pd.read_excel(open('rawdata/Web_ACS2011_Housing.xls', 'rb'),
                       sheet_name='Renter Costs', comment='#', 
                       header = 5, usecols = "A, B")
df2011_Median_Renter_county = df2011_Median_Renter[df2011_Median_Renter.Geography.str.contains('County',case=False)]
df2011_Median_Renter_county = df2011_Median_Renter_county.rename(columns = {"Estimate":"2011"})





######
df2010_Median_Renter = pd.read_excel(open('rawdata/Web_ACS2010_Housing.xls', 'rb'),
                       sheet_name='Renter Costs', comment='#', 
                       header = 5, usecols = "A, B")
df2010_Median_Renter_county = df2010_Median_Renter[df2010_Median_Renter.Geography.str.contains('County',case=False)]
df2010_Median_Renter_county = df2010_Median_Renter_county.rename(columns = {"Estimate":"2010"})


######

# %%
#########
# collect rent for each county 
df_Median_Renter_county = pd.merge(df2010_Median_Renter_county,df2011_Median_Renter_county, on='Geography',how='outer')
df_Median_Renter_county = pd.merge(df_Median_Renter_county,df2012_Median_Renter_county, on='Geography',how='outer')
df_Median_Renter_county = pd.merge(df_Median_Renter_county,df2013_Median_Renter_county, on='Geography',how='outer')
df_Median_Renter_county = pd.merge(df_Median_Renter_county,df2014_Median_Renter_county, on='Geography',how='outer')
df_Median_Renter_county = pd.merge(df_Median_Renter_county,df2015_Median_Renter_county, on='Geography',how='outer')
df_Median_Renter_county = pd.merge(df_Median_Renter_county,df2016_Median_Renter_county, on='Geography',how='outer')
df_Median_Renter_county = pd.merge(df_Median_Renter_county,df2017_Median_Renter_county, on='Geography',how='outer')
df_Median_Renter_county = pd.merge(df_Median_Renter_county,df2018_Median_Renter_county, on='Geography',how='outer')
df_Median_Renter_county = pd.merge(df_Median_Renter_county,df2019_Median_Renter_county, on='Geography',how='outer')

#########

df_Median_Renter_county = df_Median_Renter_county[:-1]
df_Median_Renter_county['average'] = df_Median_Renter_county.mean(axis=1)

# %%
# import race data over entire CA 

df2019_Hispanic_or_Latino = pd.read_excel(open('rawdata/Web_ACS2019_Pop-Race.xlsx', 'rb'),
                       sheet_name='Race and Hispanic', comment='#', 
                       header = 4, usecols = "A, D")
df2019_Hispanic_or_Latino_county = df2019_Hispanic_or_Latino[df2019_Hispanic_or_Latino.Geography.str.contains('County',case=False)]
df2019_Hispanic_or_Latino_county = df2019_Hispanic_or_Latino_county.rename(columns = {"Hispanic or Latino - Estimate":"2019"})
#####
df2019_White = pd.read_excel(open('rawdata/Web_ACS2019_Pop-Race.xlsx', 'rb'),
                       sheet_name='Race and Hispanic', comment='#', 
                       header = 4, usecols = "A, H")
df2019_White_county = df2019_White[df2019_White.Geography.str.contains('County',case=False)]
df2019_White_county = df2019_White_county.rename(columns = {"White alone, Not Hispanic or Latino - \nEstimate":"2019"})
######
df2019_Black = pd.read_excel(open('rawdata/Web_ACS2019_Pop-Race.xlsx', 'rb'),
                       sheet_name='Race and Hispanic', comment='#', 
                       header = 4, usecols = "A, L")
df2019_Black_county = df2019_Black[df2019_Black.Geography.str.contains('County',case=False)]
df2019_Black_county = df2019_Black_county.rename(columns = {"Black alone, Not Hispanic or Latino - Estimate":"2019"})
######
df2019_American_Indian_and_Alaska_Native = pd.read_excel(open('rawdata/Web_ACS2019_Pop-Race.xlsx', 'rb'),
                       sheet_name='Race and Hispanic', comment='#', 
                       header = 4, usecols = "A, P")
df2019_American_Indian_and_Alaska_Native_county = df2019_American_Indian_and_Alaska_Native[df2019_American_Indian_and_Alaska_Native.Geography.str.contains('County',case=False)]
df2019_American_Indian_and_Alaska_Native_county = df2019_American_Indian_and_Alaska_Native_county.rename(columns = {"American Indian and Alaska Native alone, Not Hispanic or Latino - Estimate":"2019"})
######
df2019_Asian = pd.read_excel(open('rawdata/Web_ACS2019_Pop-Race.xlsx', 'rb'),
                       sheet_name='Race and Hispanic', comment='#', 
                       header = 4, usecols = "A, T")
df2019_Asian_county = df2019_Asian[df2019_Asian.Geography.str.contains('County',case=False)]
df2019_Asian_county = df2019_Asian_county.rename(columns = {"Asian alone, Not Hispanic or Latino - Estimate":"2019"})


###########

df2018_Hispanic_or_Latino = pd.read_excel(open('rawdata/Web_ACS2018_Pop-Race.xlsx', 'rb'),
                       sheet_name='Race and Hispanic', comment='#', 
                       header = 4, usecols = "A, D")
df2018_Hispanic_or_Latino_county = df2018_Hispanic_or_Latino[df2018_Hispanic_or_Latino.Geography.str.contains('County',case=False)]
df2018_Hispanic_or_Latino_county = df2018_Hispanic_or_Latino_county.rename(columns = {"Hispanic or Latino - Estimate":"2018"})
#####
df2018_White = pd.read_excel(open('rawdata/Web_ACS2018_Pop-Race.xlsx', 'rb'),
                       sheet_name='Race and Hispanic', comment='#', 
                       header = 4, usecols = "A, H")
df2018_White_county = df2018_White[df2018_White.Geography.str.contains('County',case=False)]
df2018_White_county = df2018_White_county.rename(columns = {"White alone, Not Hispanic or Latino - \nEstimate":"2018"})
######
df2018_Black = pd.read_excel(open('rawdata/Web_ACS2018_Pop-Race.xlsx', 'rb'),
                       sheet_name='Race and Hispanic', comment='#', 
                       header = 4, usecols = "A, L")
df2018_Black_county = df2018_Black[df2018_Black.Geography.str.contains('County',case=False)]
df2018_Black_county = df2018_Black_county.rename(columns = {"Black alone, Not Hispanic or Latino - Estimate":"2018"})
######
df2018_American_Indian_and_Alaska_Native = pd.read_excel(open('rawdata/Web_ACS2018_Pop-Race.xlsx', 'rb'),
                       sheet_name='Race and Hispanic', comment='#', 
                       header = 4, usecols = "A, P")
df2018_American_Indian_and_Alaska_Native_county = df2018_American_Indian_and_Alaska_Native[df2018_American_Indian_and_Alaska_Native.Geography.str.contains('County',case=False)]
df2018_American_Indian_and_Alaska_Native_county = df2018_American_Indian_and_Alaska_Native_county.rename(columns = {"American Indian and Alaska Native alone, Not Hispanic or Latino - Estimate":"2018"})
######
df2018_Asian = pd.read_excel(open('rawdata/Web_ACS2018_Pop-Race.xlsx', 'rb'),
                       sheet_name='Race and Hispanic', comment='#', 
                       header = 4, usecols = "A, T")
df2018_Asian_county = df2018_Asian[df2018_Asian.Geography.str.contains('County',case=False)]
df2018_Asian_county = df2018_Asian_county.rename(columns = {"Asian alone, Not Hispanic or Latino - Estimate":"2018"})


########
df2017_Hispanic_or_Latino = pd.read_excel(open('rawdata/Web_ACS2017_Pop-Race.xlsx', 'rb'),
                       sheet_name='Race and Hispanic', comment='#', 
                       header = 5, usecols = "A, D")
df2017_Hispanic_or_Latino_county = df2017_Hispanic_or_Latino[df2017_Hispanic_or_Latino.Geography.str.contains('County',case=False)]
df2017_Hispanic_or_Latino_county = df2017_Hispanic_or_Latino_county.rename(columns = {"Estimate.1":"2017"})
#####
df2017_White = pd.read_excel(open('rawdata/Web_ACS2017_Pop-Race.xlsx', 'rb'),
                       sheet_name='Race and Hispanic', comment='#', 
                       header = 5, usecols = "A, H")
df2017_White_county = df2017_White[df2017_White.Geography.str.contains('County',case=False)]
df2017_White_county = df2017_White_county.rename(columns = {"Estimate.2":"2017"})
######
df2017_Black = pd.read_excel(open('rawdata/Web_ACS2017_Pop-Race.xlsx', 'rb'),
                       sheet_name='Race and Hispanic', comment='#', 
                       header = 5, usecols = "A, L")
df2017_Black_county = df2017_Black[df2017_Black.Geography.str.contains('County',case=False)]
df2017_Black_county = df2017_Black_county.rename(columns = {"Estimate.3":"2017"})
######
df2017_American_Indian_and_Alaska_Native = pd.read_excel(open('rawdata/Web_ACS2017_Pop-Race.xlsx', 'rb'),
                       sheet_name='Race and Hispanic', comment='#', 
                       header = 5, usecols = "A, P")
df2017_American_Indian_and_Alaska_Native_county = df2017_American_Indian_and_Alaska_Native[df2017_American_Indian_and_Alaska_Native.Geography.str.contains('County',case=False)]
df2017_American_Indian_and_Alaska_Native_county = df2017_American_Indian_and_Alaska_Native_county.rename(columns = {"Estimate.4":"2017"})
######
df2017_Asian = pd.read_excel(open('rawdata/Web_ACS2017_Pop-Race.xlsx', 'rb'),
                       sheet_name='Race and Hispanic', comment='#', 
                       header = 5, usecols = "A, T")
df2017_Asian_county = df2017_Asian[df2017_Asian.Geography.str.contains('County',case=False)]
df2017_Asian_county = df2017_Asian_county.rename(columns = {"Estimate.5":"2017"})


#######
df2016_Hispanic_or_Latino = pd.read_excel(open('rawdata/Web_ACS2016_Pop-Race.xlsx', 'rb'),
                       sheet_name='Race and Hispanic', comment='#', 
                       header = 5, usecols = "A, D")
df2016_Hispanic_or_Latino_county = df2016_Hispanic_or_Latino[df2016_Hispanic_or_Latino.Geography.str.contains('County',case=False)]
df2016_Hispanic_or_Latino_county = df2016_Hispanic_or_Latino_county.rename(columns = {"Estimate.1":"2016"})
#####
df2016_White = pd.read_excel(open('rawdata/Web_ACS2016_Pop-Race.xlsx', 'rb'),
                       sheet_name='Race and Hispanic', comment='#', 
                       header = 5, usecols = "A, H")
df2016_White_county = df2016_White[df2016_White.Geography.str.contains('County',case=False)]
df2016_White_county = df2016_White_county.rename(columns = {"Estimate.2":"2016"})
######
df2016_Black = pd.read_excel(open('rawdata/Web_ACS2016_Pop-Race.xlsx', 'rb'),
                       sheet_name='Race and Hispanic', comment='#', 
                       header = 5, usecols = "A, L")
df2016_Black_county = df2016_Black[df2016_Black.Geography.str.contains('County',case=False)]
df2016_Black_county = df2016_Black_county.rename(columns = {"Estimate.3":"2016"})
######
df2016_American_Indian_and_Alaska_Native = pd.read_excel(open('rawdata/Web_ACS2016_Pop-Race.xlsx', 'rb'),
                       sheet_name='Race and Hispanic', comment='#', 
                       header = 5, usecols = "A, P")
df2016_American_Indian_and_Alaska_Native_county = df2016_American_Indian_and_Alaska_Native[df2016_American_Indian_and_Alaska_Native.Geography.str.contains('County',case=False)]
df2016_American_Indian_and_Alaska_Native_county = df2016_American_Indian_and_Alaska_Native_county.rename(columns = {"Estimate.4":"2016"})
######
df2016_Asian = pd.read_excel(open('rawdata/Web_ACS2016_Pop-Race.xlsx', 'rb'),
                       sheet_name='Race and Hispanic', comment='#', 
                       header = 5, usecols = "A, T")
df2016_Asian_county = df2016_Asian[df2016_Asian.Geography.str.contains('County',case=False)]
df2016_Asian_county = df2016_Asian_county.rename(columns = {"Estimate.5":"2016"})

#######

df2015_Hispanic_or_Latino = pd.read_excel(open('rawdata/Web_ACS2015_Pop-Race.xlsx', 'rb'),
                       sheet_name='Race and Hispanic', comment='#', 
                       header = 5, usecols = "A, D")
df2015_Hispanic_or_Latino_county = df2015_Hispanic_or_Latino[df2015_Hispanic_or_Latino.Geography.str.contains('County',case=False)]
df2015_Hispanic_or_Latino_county = df2015_Hispanic_or_Latino_county.rename(columns = {"Estimate.1":"2015"})
#####
df2015_White = pd.read_excel(open('rawdata/Web_ACS2015_Pop-Race.xlsx', 'rb'),
                       sheet_name='Race and Hispanic', comment='#', 
                       header = 5, usecols = "A, H")
df2015_White_county = df2015_White[df2015_White.Geography.str.contains('County',case=False)]
df2015_White_county = df2015_White_county.rename(columns = {"Estimate.2":"2015"})
######
df2015_Black = pd.read_excel(open('rawdata/Web_ACS2015_Pop-Race.xlsx', 'rb'),
                       sheet_name='Race and Hispanic', comment='#', 
                       header = 5, usecols = "A, L")
df2015_Black_county = df2015_Black[df2015_Black.Geography.str.contains('County',case=False)]
df2015_Black_county = df2015_Black_county.rename(columns = {"Estimate.3":"2015"})
######
df2015_American_Indian_and_Alaska_Native = pd.read_excel(open('rawdata/Web_ACS2015_Pop-Race.xlsx', 'rb'),
                       sheet_name='Race and Hispanic', comment='#', 
                       header = 5, usecols = "A, P")
df2015_American_Indian_and_Alaska_Native_county = df2015_American_Indian_and_Alaska_Native[df2015_American_Indian_and_Alaska_Native.Geography.str.contains('County',case=False)]
df2015_American_Indian_and_Alaska_Native_county = df2015_American_Indian_and_Alaska_Native_county.rename(columns = {"Estimate.4":"2015"})
######
df2015_Asian = pd.read_excel(open('rawdata/Web_ACS2015_Pop-Race.xlsx', 'rb'),
                       sheet_name='Race and Hispanic', comment='#', 
                       header = 5, usecols = "A, T")
df2015_Asian_county = df2015_Asian[df2015_Asian.Geography.str.contains('County',case=False)]
df2015_Asian_county = df2015_Asian_county.rename(columns = {"Estimate.5":"2015"})

########

df2014_Hispanic_or_Latino = pd.read_excel(open('rawdata/Web_ACS2014_Pop-Race.xlsx', 'rb'),
                       sheet_name='Race and Hispanic', comment='#', 
                       header = 5, usecols = "A, D")
df2014_Hispanic_or_Latino_county = df2014_Hispanic_or_Latino[df2014_Hispanic_or_Latino.Geography.str.contains('County',case=False)]
df2014_Hispanic_or_Latino_county = df2014_Hispanic_or_Latino_county.rename(columns = {"Estimate.1":"2014"})
#####
df2014_White = pd.read_excel(open('rawdata/Web_ACS2014_Pop-Race.xlsx', 'rb'),
                       sheet_name='Race and Hispanic', comment='#', 
                       header = 5, usecols = "A, H")
df2014_White_county = df2014_White[df2014_White.Geography.str.contains('County',case=False)]
df2014_White_county = df2014_White_county.rename(columns = {"Estimate.2":"2014"})
######
df2014_Black = pd.read_excel(open('rawdata/Web_ACS2014_Pop-Race.xlsx', 'rb'),
                       sheet_name='Race and Hispanic', comment='#', 
                       header = 5, usecols = "A, L")
df2014_Black_county = df2014_Black[df2014_Black.Geography.str.contains('County',case=False)]
df2014_Black_county = df2014_Black_county.rename(columns = {"Estimate.3":"2014"})
######
df2014_American_Indian_and_Alaska_Native = pd.read_excel(open('rawdata/Web_ACS2014_Pop-Race.xlsx', 'rb'),
                       sheet_name='Race and Hispanic', comment='#', 
                       header = 5, usecols = "A, P")
df2014_American_Indian_and_Alaska_Native_county = df2014_American_Indian_and_Alaska_Native[df2014_American_Indian_and_Alaska_Native.Geography.str.contains('County',case=False)]
df2014_American_Indian_and_Alaska_Native_county = df2014_American_Indian_and_Alaska_Native_county.rename(columns = {"Estimate.4":"2014"})
######
df2014_Asian = pd.read_excel(open('rawdata/Web_ACS2014_Pop-Race.xlsx', 'rb'),
                       sheet_name='Race and Hispanic', comment='#', 
                       header = 5, usecols = "A, T")
df2014_Asian_county = df2014_Asian[df2014_Asian.Geography.str.contains('County',case=False)]
df2014_Asian_county = df2014_Asian_county.rename(columns = {"Estimate.5":"2014"})


##########
df2013_Hispanic_or_Latino = pd.read_excel(open('rawdata/Web_ACS2013_Pop-Race.xls', 'rb'),
                       sheet_name='Race and Hispanic', comment='#', 
                       header = 5, usecols = "A, D")
df2013_Hispanic_or_Latino_county = df2013_Hispanic_or_Latino[df2013_Hispanic_or_Latino.Geography.str.contains('County',case=False)]
df2013_Hispanic_or_Latino_county = df2013_Hispanic_or_Latino_county.rename(columns = {"Estimate.1":"2013"})
#####
df2013_White = pd.read_excel(open('rawdata/Web_ACS2013_Pop-Race.xls', 'rb'),
                       sheet_name='Race and Hispanic', comment='#', 
                       header = 5, usecols = "A, H")
df2013_White_county = df2013_White[df2013_White.Geography.str.contains('County',case=False)]
df2013_White_county = df2013_White_county.rename(columns = {"Estimate.2":"2013"})
######
df2013_Black = pd.read_excel(open('rawdata/Web_ACS2013_Pop-Race.xls', 'rb'),
                       sheet_name='Race and Hispanic', comment='#', 
                       header = 5, usecols = "A, L")
df2013_Black_county = df2013_Black[df2013_Black.Geography.str.contains('County',case=False)]
df2013_Black_county = df2013_Black_county.rename(columns = {"Estimate.3":"2013"})
######
df2013_American_Indian_and_Alaska_Native = pd.read_excel(open('rawdata/Web_ACS2013_Pop-Race.xls', 'rb'),
                       sheet_name='Race and Hispanic', comment='#', 
                       header = 5, usecols = "A, P")
df2013_American_Indian_and_Alaska_Native_county = df2013_American_Indian_and_Alaska_Native[df2013_American_Indian_and_Alaska_Native.Geography.str.contains('County',case=False)]
df2013_American_Indian_and_Alaska_Native_county = df2013_American_Indian_and_Alaska_Native_county.rename(columns = {"Estimate.4":"2013"})
######
df2013_Asian = pd.read_excel(open('rawdata/Web_ACS2013_Pop-Race.xls', 'rb'),
                       sheet_name='Race and Hispanic', comment='#', 
                       header = 5, usecols = "A, T")
df2013_Asian_county = df2013_Asian[df2013_Asian.Geography.str.contains('County',case=False)]
df2013_Asian_county = df2013_Asian_county.rename(columns = {"Estimate.5":"2013"})

#########
df2012_Hispanic_or_Latino = pd.read_excel(open('rawdata/Web_ACS2012_Pop-Race.xls', 'rb'),
                       sheet_name='Race and Hispanic', comment='#', 
                       header = 5, usecols = "A, D")
df2012_Hispanic_or_Latino_county = df2012_Hispanic_or_Latino[df2012_Hispanic_or_Latino.Geography.str.contains('County',case=False)]
df2012_Hispanic_or_Latino_county = df2012_Hispanic_or_Latino_county.rename(columns = {"Estimate.1":"2012"})
#####
df2012_White = pd.read_excel(open('rawdata/Web_ACS2012_Pop-Race.xls', 'rb'),
                       sheet_name='Race and Hispanic', comment='#', 
                       header = 5, usecols = "A, H")
df2012_White_county = df2012_White[df2012_White.Geography.str.contains('County',case=False)]
df2012_White_county = df2012_White_county.rename(columns = {"Estimate.2":"2012"})
######
df2012_Black = pd.read_excel(open('rawdata/Web_ACS2012_Pop-Race.xls', 'rb'),
                       sheet_name='Race and Hispanic', comment='#', 
                       header = 5, usecols = "A, L")
df2012_Black_county = df2012_Black[df2012_Black.Geography.str.contains('County',case=False)]
df2012_Black_county = df2012_Black_county.rename(columns = {"Estimate.3":"2012"})
######
df2012_American_Indian_and_Alaska_Native = pd.read_excel(open('rawdata/Web_ACS2012_Pop-Race.xls', 'rb'),
                       sheet_name='Race and Hispanic', comment='#', 
                       header = 5, usecols = "A, P")
df2012_American_Indian_and_Alaska_Native_county = df2012_American_Indian_and_Alaska_Native[df2012_American_Indian_and_Alaska_Native.Geography.str.contains('County',case=False)]
df2012_American_Indian_and_Alaska_Native_county = df2012_American_Indian_and_Alaska_Native_county.rename(columns = {"Estimate.4":"2012"})
######
df2012_Asian = pd.read_excel(open('rawdata/Web_ACS2012_Pop-Race.xls', 'rb'),
                       sheet_name='Race and Hispanic', comment='#', 
                       header = 5, usecols = "A, T")
df2012_Asian_county = df2012_Asian[df2012_Asian.Geography.str.contains('County',case=False)]
df2012_Asian_county = df2012_Asian_county.rename(columns = {"Estimate.5":"2012"})

#######

df2011_Hispanic_or_Latino = pd.read_excel(open('rawdata/Web_ACS2011_Pop-Race.xlsx', 'rb'),
                       sheet_name='Race and Hispanic', comment='#', 
                       header = 5, usecols = "A, D")
df2011_Hispanic_or_Latino_county = df2011_Hispanic_or_Latino[df2011_Hispanic_or_Latino.Geography.str.contains('County',case=False)]
df2011_Hispanic_or_Latino_county = df2011_Hispanic_or_Latino_county.rename(columns = {"Estimate.1":"2011"})
#####
df2011_White = pd.read_excel(open('rawdata/Web_ACS2011_Pop-Race.xlsx', 'rb'),
                       sheet_name='Race and Hispanic', comment='#', 
                       header = 5, usecols = "A, H")
df2011_White_county = df2011_White[df2011_White.Geography.str.contains('County',case=False)]
df2011_White_county = df2011_White_county.rename(columns = {"Estimate.2":"2011"})
######
df2011_Black = pd.read_excel(open('rawdata/Web_ACS2011_Pop-Race.xlsx', 'rb'),
                       sheet_name='Race and Hispanic', comment='#', 
                       header = 5, usecols = "A, L")
df2011_Black_county = df2011_Black[df2011_Black.Geography.str.contains('County',case=False)]
df2011_Black_county = df2011_Black_county.rename(columns = {"Estimate.3":"2011"})
######
df2011_American_Indian_and_Alaska_Native = pd.read_excel(open('rawdata/Web_ACS2011_Pop-Race.xlsx', 'rb'),
                       sheet_name='Race and Hispanic', comment='#', 
                       header = 5, usecols = "A, P")
df2011_American_Indian_and_Alaska_Native_county = df2011_American_Indian_and_Alaska_Native[df2011_American_Indian_and_Alaska_Native.Geography.str.contains('County',case=False)]
df2011_American_Indian_and_Alaska_Native_county = df2011_American_Indian_and_Alaska_Native_county.rename(columns = {"Estimate.4":"2011"})
######
df2011_Asian = pd.read_excel(open('rawdata/Web_ACS2011_Pop-Race.xlsx', 'rb'),
                       sheet_name='Race and Hispanic', comment='#', 
                       header = 5, usecols = "A, T")
df2011_Asian_county = df2011_Asian[df2011_Asian.Geography.str.contains('County',case=False)]
df2011_Asian_county = df2011_Asian_county.rename(columns = {"Estimate.5":"2011"})


#######

df2010_Hispanic_or_Latino = pd.read_excel(open('rawdata/Web_ACS2010_Pop-Race.xlsx', 'rb'),
                       sheet_name='Race and Hispanic', comment='#', 
                       header = 5, usecols = "A, D")
df2010_Hispanic_or_Latino_county = df2010_Hispanic_or_Latino[df2010_Hispanic_or_Latino.Geography.str.contains('County',case=False)]
df2010_Hispanic_or_Latino_county = df2010_Hispanic_or_Latino_county.rename(columns = {"Estimate.1":"2010"})
#####
df2010_White = pd.read_excel(open('rawdata/Web_ACS2010_Pop-Race.xlsx', 'rb'),
                       sheet_name='Race and Hispanic', comment='#', 
                       header = 5, usecols = "A, H")
df2010_White_county = df2010_White[df2010_White.Geography.str.contains('County',case=False)]
df2010_White_county = df2010_White_county.rename(columns = {"Estimate.2":"2010"})
######
df2010_Black = pd.read_excel(open('rawdata/Web_ACS2010_Pop-Race.xlsx', 'rb'),
                       sheet_name='Race and Hispanic', comment='#', 
                       header = 5, usecols = "A, L")
df2010_Black_county = df2010_Black[df2010_Black.Geography.str.contains('County',case=False)]
df2010_Black_county = df2010_Black_county.rename(columns = {"Estimate.3":"2010"})
######
df2010_American_Indian_and_Alaska_Native = pd.read_excel(open('rawdata/Web_ACS2010_Pop-Race.xlsx', 'rb'),
                       sheet_name='Race and Hispanic', comment='#', 
                       header = 5, usecols = "A, P")
df2010_American_Indian_and_Alaska_Native_county = df2010_American_Indian_and_Alaska_Native[df2010_American_Indian_and_Alaska_Native.Geography.str.contains('County',case=False)]
df2010_American_Indian_and_Alaska_Native_county = df2010_American_Indian_and_Alaska_Native_county.rename(columns = {"Estimate.4":"2010"})
######
df2010_Asian = pd.read_excel(open('rawdata/Web_ACS2010_Pop-Race.xlsx', 'rb'),
                       sheet_name='Race and Hispanic', comment='#', 
                       header = 5, usecols = "A, T")
df2010_Asian_county = df2010_Asian[df2010_Asian.Geography.str.contains('County',case=False)]
df2010_Asian_county = df2010_Asian_county.rename(columns = {"Estimate.5":"2010"})

# %%
# collect each race for each county

#########
df_Hispanic_or_Latino_county = pd.merge(df2010_Hispanic_or_Latino_county,df2011_Hispanic_or_Latino_county, on='Geography',how='outer')
df_Hispanic_or_Latino_county = pd.merge(df_Hispanic_or_Latino_county,df2012_Hispanic_or_Latino_county, on='Geography',how='outer')
df_Hispanic_or_Latino_county = pd.merge(df_Hispanic_or_Latino_county,df2013_Hispanic_or_Latino_county, on='Geography',how='outer')
df_Hispanic_or_Latino_county = pd.merge(df_Hispanic_or_Latino_county,df2014_Hispanic_or_Latino_county, on='Geography',how='outer')
df_Hispanic_or_Latino_county = pd.merge(df_Hispanic_or_Latino_county,df2015_Hispanic_or_Latino_county, on='Geography',how='outer')
df_Hispanic_or_Latino_county = pd.merge(df_Hispanic_or_Latino_county,df2016_Hispanic_or_Latino_county, on='Geography',how='outer')
df_Hispanic_or_Latino_county = pd.merge(df_Hispanic_or_Latino_county,df2017_Hispanic_or_Latino_county, on='Geography',how='outer')
df_Hispanic_or_Latino_county = pd.merge(df_Hispanic_or_Latino_county,df2018_Hispanic_or_Latino_county, on='Geography',how='outer')
df_Hispanic_or_Latino_county = pd.merge(df_Hispanic_or_Latino_county,df2019_Hispanic_or_Latino_county, on='Geography',how='outer')

#########

df_Hispanic_or_Latino_county = df_Hispanic_or_Latino_county[:-1]
df_Hispanic_or_Latino_county['average'] = df_Hispanic_or_Latino_county.mean(axis=1)


#########
df_White_county = pd.merge(df2010_White_county,df2011_White_county, on='Geography',how='outer')
df_White_county = pd.merge(df_White_county,df2012_White_county, on='Geography',how='outer')
df_White_county = pd.merge(df_White_county,df2013_White_county, on='Geography',how='outer')
df_White_county = pd.merge(df_White_county,df2014_White_county, on='Geography',how='outer')
df_White_county = pd.merge(df_White_county,df2015_White_county, on='Geography',how='outer')
df_White_county = pd.merge(df_White_county,df2016_White_county, on='Geography',how='outer')
df_White_county = pd.merge(df_White_county,df2017_White_county, on='Geography',how='outer')
df_White_county = pd.merge(df_White_county,df2018_White_county, on='Geography',how='outer')
df_White_county = pd.merge(df_White_county,df2019_White_county, on='Geography',how='outer')

#########

df_White_county = df_White_county[:-1]
df_White_county['average'] = df_White_county[df_White_county.columns.difference(['Geography'])].astype(float).mean(axis=1)

#########
df_Black_county = pd.merge(df2010_Black_county,df2011_Black_county, on='Geography',how='outer')
df_Black_county = pd.merge(df_Black_county,df2012_Black_county, on='Geography',how='outer')
df_Black_county = pd.merge(df_Black_county,df2013_Black_county, on='Geography',how='outer')
df_Black_county = pd.merge(df_Black_county,df2014_Black_county, on='Geography',how='outer')
df_Black_county = pd.merge(df_Black_county,df2015_Black_county, on='Geography',how='outer')
df_Black_county = pd.merge(df_Black_county,df2016_Black_county, on='Geography',how='outer')
df_Black_county = pd.merge(df_Black_county,df2017_Black_county, on='Geography',how='outer')
df_Black_county = pd.merge(df_Black_county,df2018_Black_county, on='Geography',how='outer')
df_Black_county = pd.merge(df_Black_county,df2019_Black_county, on='Geography',how='outer')

#########

df_Black_county = df_Black_county[:-1]
df_Black_county['average'] = df_Black_county[df_Black_county.columns.difference(['Geography'])].astype(float).mean(axis=1)

#########
df_Asian_county = pd.merge(df2010_Asian_county,df2011_Asian_county, on='Geography',how='outer')
df_Asian_county = pd.merge(df_Asian_county,df2012_Asian_county, on='Geography',how='outer')
df_Asian_county = pd.merge(df_Asian_county,df2013_Asian_county, on='Geography',how='outer')
df_Asian_county = pd.merge(df_Asian_county,df2014_Asian_county, on='Geography',how='outer')
df_Asian_county = pd.merge(df_Asian_county,df2015_Asian_county, on='Geography',how='outer')
df_Asian_county = pd.merge(df_Asian_county,df2016_Asian_county, on='Geography',how='outer')
df_Asian_county = pd.merge(df_Asian_county,df2017_Asian_county, on='Geography',how='outer')
df_Asian_county = pd.merge(df_Asian_county,df2018_Asian_county, on='Geography',how='outer')
df_Asian_county = pd.merge(df_Asian_county,df2019_Asian_county, on='Geography',how='outer')

#########

df_Asian_county = df_Asian_county[:-1]
df_Asian_county['average'] = df_Asian_county[df_Asian_county.columns.difference(['Geography'])].astype(float).mean(axis=1)



#########
df_American_Indian_and_Alaska_Native_county = pd.merge(df2010_American_Indian_and_Alaska_Native_county,df2011_American_Indian_and_Alaska_Native_county, on='Geography',how='outer')
df_American_Indian_and_Alaska_Native_county = pd.merge(df_American_Indian_and_Alaska_Native_county,df2012_American_Indian_and_Alaska_Native_county, on='Geography',how='outer')
df_American_Indian_and_Alaska_Native_county = pd.merge(df_American_Indian_and_Alaska_Native_county,df2013_American_Indian_and_Alaska_Native_county, on='Geography',how='outer')
df_American_Indian_and_Alaska_Native_county = pd.merge(df_American_Indian_and_Alaska_Native_county,df2014_American_Indian_and_Alaska_Native_county, on='Geography',how='outer')
df_American_Indian_and_Alaska_Native_county = pd.merge(df_American_Indian_and_Alaska_Native_county,df2015_American_Indian_and_Alaska_Native_county, on='Geography',how='outer')
df_American_Indian_and_Alaska_Native_county = pd.merge(df_American_Indian_and_Alaska_Native_county,df2016_American_Indian_and_Alaska_Native_county, on='Geography',how='outer')
df_American_Indian_and_Alaska_Native_county = pd.merge(df_American_Indian_and_Alaska_Native_county,df2017_American_Indian_and_Alaska_Native_county, on='Geography',how='outer')
df_American_Indian_and_Alaska_Native_county = pd.merge(df_American_Indian_and_Alaska_Native_county,df2018_American_Indian_and_Alaska_Native_county, on='Geography',how='outer')
df_American_Indian_and_Alaska_Native_county = pd.merge(df_American_Indian_and_Alaska_Native_county,df2019_American_Indian_and_Alaska_Native_county, on='Geography',how='outer')

#########

df_American_Indian_and_Alaska_Native_county = df_American_Indian_and_Alaska_Native_county[:-1]
df_American_Indian_and_Alaska_Native_county['average'] = df_American_Indian_and_Alaska_Native_county[df_American_Indian_and_Alaska_Native_county.columns.difference(['Geography'])].astype(float).mean(axis=1)

# %%
# average white popluation for each county over years 2010 - 2019 
df_White_county_avg = df_White_county[['Geography','average']]
df_White_county_avg = df_White_county_avg.rename(columns = {"average":"White_avg"})

# average black popluation for each county over years 2010 - 2019 
df_Black_county_avg = df_Black_county[['Geography','average']]
df_Black_county_avg = df_Black_county_avg.rename(columns = {"average":"Black_avg"})

# average asian popluation for each county over years 2010 - 2019 
df_Asian_county_avg = df_Asian_county[['Geography','average']]
df_Asian_county_avg = df_Asian_county_avg.rename(columns = {"average":"Asian_avg"})

# average Hispanic_or_Latino popluation for each county over years 2010 - 2019 
df_Hispanic_or_Latino_county_avg = df_Hispanic_or_Latino_county[['Geography','average']]
df_Hispanic_or_Latino_county_avg = df_Hispanic_or_Latino_county_avg.rename(columns = {"average":"Hispanic_or_Latino_avg"})

# average American_Indian_and_Alaska_Native popluation for each county over years 2010 - 2019 
df_American_Indian_and_Alaska_Native_county_avg = df_American_Indian_and_Alaska_Native_county[['Geography','average']]
df_American_Indian_and_Alaska_Native_county_avg = df_American_Indian_and_Alaska_Native_county_avg.rename(columns = {"average":"American_Indian_and_Alaska_Native_avg"})

# %%
# compute average median household income over entire state CA from 2010 to 2019 

df_Median_household_income_county_avg = df_Median_household_income_county[['Geography','average']]
df_Median_household_income_county_avg['average'] = df_Median_household_income_county_avg['average']/12
df_Median_household_income_county_avg = df_Median_household_income_county_avg.rename(columns = {"average":"Median_Household_income_avg"})

# compute average median family income over entire state CA from 2010 to 2019 
df_Median_family_income_county_avg =  df_Median_family_income_county[['Geography','average']]
df_Median_family_income_county_avg['average'] = df_Median_family_income_county_avg['average']/12
df_Median_family_income_county_avg = df_Median_family_income_county_avg.rename(columns = {"average":"Median_Family_income_avg"})

# compute average median rent over entire state CA from 2010 to 2019 
df_Median_Renter_county_avg = df_Median_Renter_county[['Geography','average']]
df_Median_Renter_county_avg = df_Median_Renter_county_avg.rename(columns = {"average":"Median_rent_avg"})
# Out:
# /Users/Pi/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /Users/Pi/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':

# %%
# compute Average race over years 2010-2019 for each county and plot it 

index = df_Population_County_avg ['Geography'].tolist()
avg_population = df_Population_County_avg['population_avg'].tolist()
avg_White = df_White_county_avg['White_avg'].tolist()
avg_Black = df_Black_county_avg['Black_avg'].tolist()
avg_Asian = df_Asian_county_avg['Asian_avg'].tolist()
avg_Hispanic_or_Latino = df_Hispanic_or_Latino_county_avg['Hispanic_or_Latino_avg'].tolist()
avg_American_Indian_and_Alaska_Native = df_American_Indian_and_Alaska_Native_county_avg['American_Indian_and_Alaska_Native_avg'].tolist()

avg_median_family_income = df_Median_family_income_county_avg["Median_Family_income_avg"].tolist()


df = pd.DataFrame({'Average_median_family_income': avg_median_family_income,
                    'Average_population': avg_population,
                   'Average_White': avg_White, 
                   'Average_Black': avg_Black, 
                   'Average_Asian': avg_Asian, 
                   'Average_Hispanic_or_Latino': avg_Hispanic_or_Latino, 
                   'Average_American_Indian_and_Alaska_Native ': avg_American_Indian_and_Alaska_Native, 
                  }, index=index)



top_10_counties_by_median_family_income = df.sort_values(by=['Average_median_family_income'], ascending=False)[:10]

top_10_counties_race = top_10_counties_by_median_family_income.loc[:, top_10_counties_by_median_family_income.columns != 'Average_median_family_income']


import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams["figure.figsize"] = [15, 5]
ax = top_10_counties_race.plot.barh(width=0.5, stacked=True)
plt.title('Average race over years 2010-2019 for each county')
BIGGER_SIZE = 16
plt.rc('font', size=BIGGER_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=BIGGER_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=BIGGER_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=BIGGER_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=BIGGER_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=12)    # legend fontsize
# plt.savefig('race_bar' + '.png', bbox_inches = "tight", transparent=True)

# %%
# compute Average income and rent over years 2010-2019 for each county and plot 

index = df_Median_household_income_county_avg ['Geography'].tolist()
avg_median_rent = df_Median_Renter_county_avg['Median_rent_avg'].tolist()
avg_median_household_income = df_Median_household_income_county_avg ['Median_Household_income_avg'].tolist()
avg_population = df_Population_County_avg['population_avg']
avg_median_family_income = df_Median_family_income_county_avg["Median_Family_income_avg"].tolist()

df = pd.DataFrame({'Average_median_family_income': avg_median_family_income,
                   'Average_median_household_income': avg_median_household_income, 
                   'Average_median_rent': avg_median_rent}, index=index)

top_10_counties_by_median_family_income = df.sort_values(by=['Average_median_family_income'], ascending=False)[:10]


plt.rcParams["figure.figsize"] = [15, 8]
ax = top_10_counties_by_median_family_income.plot.barh()
plt.title('Average income and rent over years 2010-2019 for each county')
SMALL_SIZE = 8
MEDIUM_SIZE = 10
BIGGER_SIZE = 16
plt.rc('font', size=BIGGER_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=BIGGER_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=BIGGER_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=BIGGER_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=BIGGER_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=12)    # legend fontsize
# plt.savefig('income_rent_bar' + '.png', bbox_inches = "tight", transparent=True)

# %%
# plot Average Median Rent over CA (dollars) vs time (2010-2019)

import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams["figure.figsize"] = [5, 5]

df_Median_Renter_county.mean(axis=0)[:-1].plot.line(style = '-ok')
plt.ylabel('Average Median Rent over CA (dollars)')
plt.xlabel('time (year)')
# plt.title(name)
SMALL_SIZE = 8
MEDIUM_SIZE = 10
BIGGER_SIZE = 16
plt.rc('font', size=BIGGER_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=BIGGER_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=BIGGER_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=BIGGER_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=BIGGER_SIZE)    # fontsize of the tick labels
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title
# plt.savefig('rent_vs_time' + '.png', bbox_inches = "tight", transparent=True)
plt.show()

# %%
# plot Average Median Rent and income over CA (dollars) vs time (2010-2019)

import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams["figure.figsize"] = [5, 5]

index = [2010,2011,2012,2013,2014,2015,2016,2017,2018,2019]
avg_Median_household_income_over_CA = df_Median_household_income_county.mean(axis=0)[:-1].tolist()
avg_Median_family_income_over_CA = df_Median_family_income_county.mean(axis=0)[:-1].tolist()
avg_Median_rent_over_CA = df_Median_Renter_county.mean(axis=0)[:-1].tolist()


df = pd.DataFrame({'avg_Median_family_income_over_CA':avg_Median_family_income_over_CA,
                   'avg_Median_household_income_over_CA':avg_Median_household_income_over_CA,
                   'avg_Median_rent_over_CA': avg_Median_rent_over_CA}, index=index)

df.plot.line(style = ['-or', '-ob', '-ok'])
plt.ylabel('income or rent (dollars)')
plt.xlabel('time (year)')
# plt.title(name)
SMALL_SIZE = 8
MEDIUM_SIZE = 9
BIGGER_SIZE = 16
plt.rc('font', size=BIGGER_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=BIGGER_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=BIGGER_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=BIGGER_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=BIGGER_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title
# plt.savefig('income_rent_vs_time' + '.png', bbox_inches = "tight", transparent=True)
plt.show()
